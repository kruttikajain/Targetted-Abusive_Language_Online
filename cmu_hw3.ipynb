# %% [markdown]
# # Abusive Language Online
#
# Predition1: predict OFF/NOT
#
# * Dataset: [data](http://demo.clab.cs.cmu.edu/ethical_nlp2019/homeworks/hw3/hw3.html)
#
#
# 1.   train.tsv
# 2.   dev.tsv
# 3.   test.tsv
#
# * Need manually add log.txt
# * Mount drive to load GloVe embeddings

# %% [markdown]
# # Import useful lib

# %%
import os
import sys
from logging import handlers
from pathlib import Path
import logging
import time
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
from tqdm import tqdm
import math
import random 

from sklearn.model_selection import train_test_split
from sklearn import metrics
from sklearn.model_selection import KFold
from sklearn.model_selection import StratifiedShuffleSplit

from keras.preprocessing.text import Tokenizer
from keras.preprocessing.sequence import pad_sequences
from keras.layers import Dense, Input, LSTM, Embedding, Dropout, Activation, CuDNNGRU, CuDNNLSTM, Conv1D
from keras.layers import Bidirectional, GlobalMaxPool1D
from keras.models import Model
from keras import initializers, regularizers, constraints, optimizers, layers

from os import path
from PIL import Image
from wordcloud import WordCloud, STOPWORDS, ImageColorGenerator
# %matplotlib inline 
import matplotlib.pyplot as plt
# Out:
# Using TensorFlow backend.

# %% [markdown]
# # Prepare logging file

# %%
def init_logger(log_file):
    if not os.path.exists(log_file):
        os.makedirs(os.path.dirname(log_file))

    log = logging.getLogger('')
    log.setLevel(logging.INFO)
    output_format = logging.Formatter(fmt='%(asctime)s %(levelname)-8s %(message)s', datefmt='%Y-%m-%d %H:%M:%S')
    std_out_handler = logging.StreamHandler(sys.stdout)
    std_out_handler.setFormatter(output_format)
    logging.getLogger().addHandler(std_out_handler)
    file_handler = logging.handlers.RotatingFileHandler(log_file, maxBytes=(1048576*5), backupCount=7)
    file_handler.setFormatter(output_format)
    logging.getLogger().addHandler(file_handler)

init_logger('./log.txt')
logging.info('=============start=================')
logging.info('logging file prepared')
# Out:
# 2020-05-02 04:36:17 INFO     =============start=================
# 2020-05-02 04:36:17 INFO     logging file prepared

# %% [markdown]
# # Data proprecessing

# %% [markdown]
# ## Reading data

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
def load_data():
    logging.info('loading the dataset...')
    train_df = pd.read_csv("./train.tsv", sep="\t")
    val_df = pd.read_csv("./dev.tsv", sep="\t")
    test_df = pd.read_csv("./test.tsv", sep="\t")
    
    # shape of df, column names
    logging.info('Train shape : ' + str(train_df.shape)) # 'text', 'label', 'category'
    logging.info('Val shape: ' + str(val_df.shape))
    logging.info('Test shape: ' + str(test_df.shape))
    
    logging.info('train_df.columns: ' + train_df.columns)
    logging.info('val_df.columns: ' + val_df.columns)
    logging.info('test_df.columns: ' + test_df.columns)

    return train_df, val_df, test_df

train_df, val_df, test_df = load_data()
# Out:
# 2020-05-02 05:10:15 INFO     loading the dataset...
# 2020-05-02 05:10:15 INFO     Train shape : (10592, 3)
# 2020-05-02 05:10:15 INFO     Val shape: (1324, 3)
# 2020-05-02 05:10:15 INFO     Test shape: (1324, 1)
# 2020-05-02 05:10:15 INFO     Index(['train_df.columns: text', 'train_df.columns: label',
#        'train_df.columns: category'],
#       dtype='object')
# 2020-05-02 05:10:15 INFO     Index(['val_df.columns: text', 'val_df.columns: label',
#        'val_df.columns: category'],
#       dtype='object')
# 2020-05-02 05:10:15 INFO     Index(['test_df.columns: text'], dtype='object')

# %%
train_df.head()
# Out:
#                                                                                                                                  text  ... category
# 0  @USER @USER You are an embarrassing citizen!!                                                                                       ...  TIN
# 1  @USER Seems hard to believe that you stood next to a guy wearing those shorts and didn't masturbate but I'll take your word for it  ...  TIN
# 2  @USER @USER @USER Wow !!! no wonder the Liberals only got worse as a party of bullies to women...??? no accountability.             ...  TIN
# 3  @USER @USER And not all idiots grandstands like he did                                                                              ...  TIN
# 4  @USER Bring on the hypocrite gungrabber. MAGA                                                                                       ...  TIN
#
# [5 rows x 3 columns]

# %% [markdown]
# **Attributes in data:**
#
#
# ***Trainning data:***  (10592, 3) \\
#
# * **text:** \\
# tweet content
#
# * **label:** \\
# 1.   (NOT) Not Offensive - This post does not contain offense or profanity
# 2.   (OFF) Offensive - This post contains offensive language or a targeted (veiled or direct) offense
#
# * **category:** (if label is 'OFF') \\
# 1.   (TIN) Targeted Insult and Threats - A post containing an insult or threat to an individual, a group, or others
# 2.   (UNT) Untargeted - A post containing non-targeted profanity and swearing.
#
# ***Validation data:***  (1324, 3) \\
#
# ***Testing data***:  'text' (1324, 1) \\
# * **text**

# %% [markdown]
# ## Data cleaning

# %%
def data_cleaning(train_df, val_df, test_df):
    # shuffle data
    train_df = train_df.sample(frac=1, random_state=2020).reset_index(drop=True)
    
    # lo lowercae
    train_df['text'] = train_df['text'].str.lower()
    val_df['text'] = val_df['text'].str.lower()
    test_df['text'] = test_df['text'].str.lower()

    # delete "noise words"
    noise = ["url","user","@","&amp;","#","-",'.',"!","?","rt","dm","retweet","rt","dm"]
    for WORD in noise:
        train_df['text'] = train_df['text'].str.replace(WORD, '')
        val_df['text'] = val_df['text'].str.replace(WORD, '')
        test_df['text'] = test_df['text'].str.replace(WORD, '')

    # change label to 0/a
    train_df['label'] = train_df['label'].map({'OFF': 1, 'NOT': 0})
    val_df['label'] = val_df['label'].map({'OFF': 1, 'NOT': 0})

    # one-hot encoding of category
    train_df = pd.concat([train_df,pd.get_dummies(train_df['category'], prefix='category')],axis=1)
    train_df.drop(['category'],axis=1, inplace=True)
    
    val_df = pd.concat([val_df,pd.get_dummies(val_df['category'], prefix='category')],axis=1)
    val_df.drop(['category'],axis=1, inplace=True)
    return train_df, val_df, test_df

train_df, val_df, test_df = data_cleaning(train_df, val_df, test_df)

# %%
val_df.head(10)
# Out:
#                                                                                                                                                                          text  ...  category_UNT
# 0   she should ask a few native americans what their take on this is                                                                                                           ...  1
# 1    go home you’re drunk  maga trump2020 👊🇺🇸👊                                                                                                                                 ...  0
# 2  amazon is investigating chinese employees who are selling internal data to thirdpay sellers looking for an edge in the competitive marketplace  amazon maga kag china tcot  ...  0
# 3   someone should'vetaken" this piece of shit to a volcano 😂"                                                                                                                 ...  1
# 4    obama wanted liberals  illegals to move into red states                                                                                                                   ...  0
# 5   liberals are all kookoo                                                                                                                                                    ...  0
# 6    oh noes tough shit                                                                                                                                                        ...  1
# 7   was literally just talking about this lol all mass shootings like that have been set ups it’s propaganda used to divide us on major issues like gun control and terrorism  ...  0
# 8   buy more icecream                                                                                                                                                          ...  0
# 9   canada doesn’t need another cuck we already have enough looneyleft liberals f**king up our great country qproofs trudeaumustgo                                             ...  0
#
# [10 rows x 4 columns]

# %% [markdown]
# Check the content of abusive text

# %%
abusive_df = train_df.loc[train_df['label'] == 1]
# pd.set_option('display.max_rows', None)
# pd.set_option('display.width', None)
pd.set_option('display.max_colwidth', -1)
abusive_df['text'].head(5)
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:4: FutureWarning: Passing a negative integer is deprecated in version 1.0 and will not be supported in future version. Instead, use None to not limit the column width.
#   after removing the cwd from sys.path.
# 0      didn't this trashy thing sleep her way to the top with married men
# 1       gfy the nfl should get no protection from the policeand no suppo from our militarythe league will slowly die on this road of shame
# 10     👀 sitting here thinking he has a killer porn stache
# 13    all trump's and pense 2020 merch is being made is china and not the usa    maga    votethemout2018  trumpsarmy
# 16     gun control now enough is enough
# Name: text, dtype: object

# %% [markdown]
# ## Data distribution and visualization

# %%
# count how many letters in a sentence
def label_distribution(train_df):
    #  length of text
    count = train_df['text'].str.split().apply(len).value_counts()
    count.sort_index(inplace=True)
    count.index = count.index.astype(str) + ' words:'
    # logging.info(count[0:5])
    # logging.info(count[-5:])
    plt.plot(range(len(count)), count, color='blue')
    plt.title("Text length")
    plt.show()
    # label distribution
    logging.info('number of label = 1 : ' + str((train_df['label'] != 0).sum()))
    logging.info('number of category_TIN = 1: ' + str((train_df['category_TIN'] != 0).sum()))
    logging.info('number of category_UNT = 1: ' + str((train_df['category_UNT'] != 0).sum()))

    # plot histogram
    train_df['label'].plot.hist(bins=2, title='label distribution')
    plt.show()

label_distribution(train_df)
# Out:
# 2020-05-02 04:36:47 INFO     number of label = 1 : 3520
# 2020-05-02 04:36:47 INFO     number of category_TIN = 1: 3089
# 2020-05-02 04:36:47 INFO     number of category_UNT = 1: 431

# %% [markdown]
# **Property of dataset**
#
# *   **Length of text:** [2, 60]
#
# *   **label:**
# 1.   label = 0: 7072
# 2.   label = 1: 3520
#
# * Among label = 1: \\
# 1.   category_TIN = 1: 3089
# 2.   category_UNT = 1: 431

# %% [markdown]
# Word cloud

# %%
# word cloud
normal_df = train_df.loc[train_df.label == 0]
abusive_df = train_df.loc[train_df.label == 1]

normal_text_array = np.array(normal_df['text'])
abusive_text_array = np.array(abusive_df['text'])

normal_text = ''.join(normal_text_array)
abusive_text = ''.join(abusive_text_array)

logging.info("convert to text finished")
# Out:
# 2020-05-02 04:36:51 INFO     convert to text finished

# %%
# normal
wordcloud = WordCloud(background_color="white").generate(normal_text)
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis("off")
plt.show()

# abusive
wordcloud = WordCloud(background_color="white").generate(abusive_text)
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis("off")
plt.show()

# %% [markdown]
# Delete some common words

# %%
normal_text = normal_text.replace('liberal','',1000).replace('people','',1000).replace('will','',1000)
abusive_text = abusive_text.replace('liberal','',1000).replace('people','',1000).replace('will','',1000)

# %%
# normal
wordcloud = WordCloud(background_color="white").generate(normal_text)
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis("off")
plt.show()

# abusive
wordcloud = WordCloud(background_color="white").generate(abusive_text)
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis("off")
plt.show()

# %% [markdown]
# # Split data to X and y

# %% [markdown]
# Split data to X and y

# %%
def split_train_val(train_df, val_df, test_df):
    logging.info('splitting X and y ...')
    train_X = train_df["text"].fillna("_na_").values
    val_X = val_df["text"].fillna("_na_").values
    test_X = test_df["text"].fillna("_na_").values

    train_y = train_df['label'].values
    val_y = val_df['label'].values

    logging.info('finished splitting X and y')
    return train_X, val_X, test_X, train_y, val_y

train_X, val_X, test_X, train_y, val_y = split_train_val(train_df, val_df, test_df)
# Out:
# 2020-05-02 05:10:39 INFO     splitting X and y ...
# 2020-05-02 05:10:39 INFO     finished splitting X and y

# %%
print(train_X.shape, train_y.shape)
print(val_X.shape, val_y.shape)
# Out:
# (10592,) (10592,)
# (1324,) (1324,)

# %% [markdown]
# Tokenize and padding each sentence, split datafram to attributes and labels

# %%
# each word embedding to 300 dimension
embed_size = 300
# count of vocabulary words
max_features = 50000
# length of each sentences
max_len = 70

def token_sentence(train_X, val_X, test_X ):
    logging.info('tokenizing sentence...')
    tokenizer = Tokenizer(num_words=max_features)
    tokenizer.fit_on_texts(list(train_X))
    train_X = tokenizer.texts_to_sequences(train_X)
    val_X = tokenizer.texts_to_sequences(val_X)
    test_X = tokenizer.texts_to_sequences(test_X)

    logging.info('padding sentence...')
    train_X = pad_sequences(train_X, maxlen=max_len)
    val_X = pad_sequences(val_X, maxlen=max_len)
    test_X = pad_sequences(test_X, maxlen=max_len)

    logging.info('all finished...')
    return train_X, val_X, test_X, tokenizer

train_X, val_X, test_X, tokenizer = token_sentence(train_X, val_X, test_X)
# Out:
# 2020-05-02 05:10:52 INFO     tokenizing sentence...
# 2020-05-02 05:10:52 INFO     padding sentence...
# 2020-05-02 05:10:52 INFO     all finished...

# %%
train_X.shape
# Out:
# (10592, 70)

# %% [markdown]
# # Train model

# %% [markdown]
# ## Model1: base line

# %%
from sklearn import tree
from sklearn.linear_model import LogisticRegression
from sklearn.naive_bayes import GaussianNB

from sklearn.metrics import accuracy_score, f1_score

# %% [markdown]
# ### Decision tree

# %%
def dt_model(train_X, train_y, val_X, cal_y):
    dt_clf = tree.DecisionTreeClassifier()
    dt_clf = dt_clf.fit(train_X, train_y)
    pred_val_y = dt_clf.predict(val_X).reshape(-1,1)
    dt_acc = accuracy_score(pred_val_y, val_y)
    dt_f1_score = f1_score(pred_val_y, val_y)
    return dt_acc, dt_f1_score

# %%
dt_acc, dt_f1_score = dt_model(train_X, train_y, val_X, val_y)
print('dt_acc: ', dt_acc, ', dt_f1_score: ',  dt_f1_score)
# Out:
# dt_acc:  0.5574018126888217 , dt_f1_score:  0.34743875278396436

# %% [markdown]
# ### LogisticRegression

# %%
def lr_model(train_X, train_y, val_X, cal_y):
    lr_clf = LogisticRegression(random_state=0, max_iter=4000).fit(train_X, train_y)
    pred_val_y = lr_clf.predict(val_X).reshape(-1,1)
    lr_acc = accuracy_score(pred_val_y, val_y)
    lr_f1_score = f1_score(pred_val_y, val_y)
    return lr_acc, lr_f1_score

# %%
lr_acc, lr_f1_score = lr_model(train_X, train_y, val_X, val_y)
print('lr_acc: ', lr_acc, ', lr_f1_score: ',  lr_f1_score)
# Out:
# lr_acc:  0.6661631419939577 , lr_f1_score:  0.0045045045045045045

# %% [markdown]
# ### GaussianNB

# %%
def gNB_model(train_X, train_y, val_X, cal_y):
    gNB_clf = GaussianNB()
    gNB_clf = gNB_clf.fit(train_X, train_y)
    pred_val_y = gNB_clf.predict(val_X).reshape(-1,1)
    gNB_acc = accuracy_score(pred_val_y, val_y)
    gNB_f1_score = f1_score(pred_val_y, val_y)
    return gNB_acc, gNB_f1_score

# %%
gNB_acc, gNB_f1_score = gNB_model(train_X, train_y, val_X, val_y)
print('gNB_acc: ', gNB_acc, ', gNB_f1_score: ',  gNB_f1_score)
# Out:
# gNB_acc:  0.3323262839879154 , gNB_f1_score:  0.49829738933030654

# %% [markdown]
# ## Model2 : LSTM + Without Pretrained Embeddings:

# %%
import tensorflow as tf
from tensorflow.keras import layers

model = tf.keras.Sequential()

# Add an Embedding layer expecting input vocab of size 50000, and
# output embedding dimension of size 300.
model.add(layers.Embedding(input_dim=50000, output_dim=300))

# Add a LSTM layer with 128 internal units.
model.add(layers.LSTM(128))
model.add(layers.Dense(10,activation="relu"))
model.add(layers.Dropout(0.2))
model.add(layers.Dense(1, activation="sigmoid"))

model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# embedding_1 (Embedding)      (None, None, 300)         15000000
# _________________________________________________________________
# lstm_1 (LSTM)                (None, 128)               219648
# _________________________________________________________________
# dense_2 (Dense)              (None, 10)                1290
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 10)                0
# _________________________________________________________________
# dense_3 (Dense)              (None, 1)                 11
# =================================================================
# Total params: 15,220,949
# Trainable params: 15,220,949
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])

from tensorflow.keras.callbacks import EarlyStopping
callbacks = EarlyStopping(monitor='val_loss', min_delta=0, patience = 2)
history = model.fit(train_X, 
                    train_y, 
                    batch_size=512, 
                    epochs=14, 
                    validation_data=(val_X, val_y),
                    callbacks=callbacks
                    )
# Out:
# Epoch 1/14
# 21/21 [==============================] - 25s 1s/step - loss: 0.6391 - accuracy: 0.6615 - val_loss: 0.6178 - val_accuracy: 0.6677
# Epoch 2/14
# 21/21 [==============================] - 27s 1s/step - loss: 0.5653 - accuracy: 0.6918 - val_loss: 0.5633 - val_accuracy: 0.7039
# Epoch 3/14
# 21/21 [==============================] - 25s 1s/step - loss: 0.4095 - accuracy: 0.8374 - val_loss: 0.5775 - val_accuracy: 0.7198
# Epoch 4/14
# 21/21 [==============================] - 25s 1s/step - loss: 0.2467 - accuracy: 0.9078 - val_loss: 0.7376 - val_accuracy: 0.7077

# %%
# plot history
# Plot training & validation accuracy values
import matplotlib.pyplot as plt 
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('Model accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Train', 'Val'], loc='upper left')
plt.show()

# Plot training & validation loss values
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Val'], loc='upper left')
plt.show()

# %%
# validation the model(f1-score)
pred_noemb_val_y = model.predict([val_X], batch_size=1024, verbose=1)
print(pred_noemb_val_y)
threshes=[]
f1_scores=[]
accuracy_scores=[]
for thresh in np.arange(0.1, 0.801, 0.01):
    thresh = np.round(thresh, 2)
    threshes.append(thresh)
    logging.info("F1 score at threshold {0} is {1}".format(thresh, metrics.f1_score(val_y, (pred_noemb_val_y>thresh).astype(int))))
    f1_scores.append(metrics.f1_score(val_y, (pred_noemb_val_y>thresh).astype(int)))
    print("Accuracy at threshold {0} is {1}".format(thresh, metrics.accuracy_score(val_y, (pred_noemb_val_y>thresh).astype(int))))
    accuracy_scores.append(metrics.accuracy_score(val_y, (pred_noemb_val_y>thresh).astype(int)))

# %%
# plot two measures
plt.plot(threshes, f1_scores, color='blue', label='f1')
plt.plot(threshes, accuracy_scores, color='orange', label='acc')
plt.title('f1_scores/acc')
plt.ylabel('f1_scores/acc')
plt.xlabel('threshold')
plt.legend()
plt.show()

# %% [markdown]
# ## Model3: LSTM + Pretrained embeddings
#
# Different Embeddings:
#
# GoogleNews-vectors-negative300 - https://code.google.com/archive/p/word2vec/
#
# glove.840B.300d - https://nlp.stanford.edu/projects/glove/
# paragram_300_sl999 - https://cogcomp.org/page/resource_view/106
#
# wiki-news-300d-1M - https://fasttext.cc/docs/en/english-vectors.html

# %%
import io
embeddings_index = {}
logging.info("Loading Glove Model")
with io.open('drive/My Drive/Colab Notebooks/246Project/glove.840B.300d.txt', encoding='utf8') as f:
    for line in f:
        values = line.split()
        word = ''.join(values[:-300])
        coefs = np.asarray(values[-300:], dtype='float32')
        embeddings_index[word] = coefs
logging.info("Loading Glove Model Done")
# Out:
# 2020-05-02 05:03:51 INFO     Loading Glove Model
# 2020-05-02 05:06:52 INFO     Loading Glove Model Done

# %%
all_embs = np.stack(embeddings_index.values())
emb_mean,emb_std = all_embs.mean(), all_embs.std()
embed_size = all_embs.shape[1]

print(all_embs.shape, emb_mean, emb_std, embed_size )
# Out:
# /usr/local/lib/python3.6/dist-packages/IPython/core/interactiveshell.py:2822: FutureWarning: arrays to stack must be passed as a "sequence" type such as list or tuple. Support for non-sequence iterables such as generators is deprecated as of NumPy 1.16 and will raise an error in the future.
#   if self.run_code(code, result):
# (2195893, 300) -0.005839112 0.48782477 300

# %%
word_index = tokenizer.word_index
len(word_index)
# Out:
# 19626

# %%
nb_words = min(max_features, 1 + len(word_index))
nb_words
# Out:
# 19627

# %%
embedding_matrix = np.random.normal(emb_mean, emb_std, (nb_words, embed_size))
embedding_matrix.shape
# Out:
# (19627, 300)

# %%
for word, i in word_index.items(): 
    if i >= max_features: continue
    embedding_vector = embeddings_index.get(word)
    if embedding_vector is not None: 
        embedding_matrix[i] = embedding_vector
print(embedding_matrix.shape)
# Out:
# (19627, 300)
# [[ 0.16513922 -0.12608104  0.42797586 ...  0.6024055   0.49297647
#   -0.20777127]
#  [ 0.27204001 -0.06203    -0.1884     ...  0.13015001 -0.18317001
#    0.1323    ]
#  [-0.084961    0.50199997  0.0023823  ... -0.21511    -0.26304001
#   -0.0060173 ]
#  [ 0.31924     0.06316    -0.27858001 ...  0.082745    0.097801
#    0.25044999]
#  [ 0.043798    0.024779   -0.20937    ... -0.30098999 -0.14584
#    0.28187999]]

# %%
import tensorflow as tf
from tensorflow.keras import layers
from keras.initializers import Constant

model = tf.keras.Sequential()
model.add(layers.Embedding(nb_words,
                            300,
                            weights=[embedding_matrix],
                            input_length=max_len,
                            trainable=False))
model.add(layers.LSTM(128))
model.add(layers.Dense(10,activation="relu"))
model.add(layers.Dropout(0.2))
model.add(layers.Dense(1, activation="sigmoid"))
model.summary()
# Out:
# Model: "sequential_3"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# embedding_3 (Embedding)      (None, 70, 300)           5888100
# _________________________________________________________________
# lstm_3 (LSTM)                (None, 128)               219648
# _________________________________________________________________
# dense_6 (Dense)              (None, 10)                1290
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 10)                0
# _________________________________________________________________
# dense_7 (Dense)              (None, 1)                 11
# =================================================================
# Total params: 6,109,049
# Trainable params: 220,949
# Non-trainable params: 5,888,100
# _________________________________________________________________

# %%
model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])

# %%
from tensorflow.keras.callbacks import EarlyStopping

callbacks = EarlyStopping(monitor='val_loss', min_delta=0, patience = 2)

history = model.fit(train_X, 
                    train_y, 
                    batch_size=512, 
                    epochs=15, 
                    validation_data=(val_X, val_y),
                    callbacks=callbacks
                    )
# Out:
# Epoch 1/15
# 21/21 [==============================] - 18s 851ms/step - loss: 0.6441 - accuracy: 0.6406 - val_loss: 0.6135 - val_accuracy: 0.6677
# Epoch 2/15
# 21/21 [==============================] - 18s 836ms/step - loss: 0.5830 - accuracy: 0.6865 - val_loss: 0.5622 - val_accuracy: 0.7213
# Epoch 3/15
# 21/21 [==============================] - 17s 831ms/step - loss: 0.5289 - accuracy: 0.7357 - val_loss: 0.5163 - val_accuracy: 0.7576
# Epoch 4/15
# 21/21 [==============================] - 17s 829ms/step - loss: 0.4971 - accuracy: 0.7527 - val_loss: 0.4932 - val_accuracy: 0.7681
# Epoch 5/15
# 21/21 [==============================] - 17s 826ms/step - loss: 0.4800 - accuracy: 0.7626 - val_loss: 0.4904 - val_accuracy: 0.7727
# Epoch 6/15
# 21/21 [==============================] - 17s 825ms/step - loss: 0.4675 - accuracy: 0.7683 - val_loss: 0.4800 - val_accuracy: 0.7772
# Epoch 7/15
# 21/21 [==============================] - 17s 828ms/step - loss: 0.4566 - accuracy: 0.7856 - val_loss: 0.4840 - val_accuracy: 0.7727
# Epoch 8/15
# 21/21 [==============================] - 17s 827ms/step - loss: 0.4474 - accuracy: 0.7981 - val_loss: 0.4847 - val_accuracy: 0.7666

# %%
# Plot training & validation accuracy values
import matplotlib.pyplot as plt 
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('Model accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Train', 'Val'], loc='upper left')
plt.show()

# Plot training & validation loss values
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Val'], loc='upper left')
plt.show()

# %%
# validation the model(f1-score)
pred_noemb_val_y = model.predict([val_X], batch_size=1024, verbose=1)
print(pred_noemb_val_y)
threshes=[]
f1_scores=[]
accuracy_scores=[]
for thresh in np.arange(0.1, 0.801, 0.01):
    thresh = np.round(thresh, 2)
    threshes.append(thresh)
    logging.info("F1 score at threshold {0} is {1}".format(thresh, metrics.f1_score(val_y, (pred_noemb_val_y>thresh).astype(int))))
    f1_scores.append(metrics.f1_score(val_y, (pred_noemb_val_y>thresh).astype(int)))
    print("Accuracy at threshold {0} is {1}".format(thresh, metrics.accuracy_score(val_y, (pred_noemb_val_y>thresh).astype(int))))
    accuracy_scores.append(metrics.accuracy_score(val_y, (pred_noemb_val_y>thresh).astype(int)))
# Out:
# 2/2 [==============================] - 0s 116ms/step
# [[0.22785336]
#  [0.44823056]
#  [0.08510813]
#  ...
#  [0.5191109 ]
#  [0.3782552 ]
#  [0.3307072 ]]
# 2020-05-02 05:19:47 INFO     F1 score at threshold 0.1 is 0.5555555555555555
# Accuracy at threshold 0.1 is 0.486404833836858
# 2020-05-02 05:19:47 INFO     F1 score at threshold 0.11 is 0.5695097380792479
# Accuracy at threshold 0.11 is 0.5158610271903323
# 2020-05-02 05:19:47 INFO     F1 score at threshold 0.12 is 0.5778997940974605
# Accuracy at threshold 0.12 is 0.5354984894259819
# 2020-05-02 05:19:47 INFO     F1 score at threshold 0.13 is 0.5846153846153845
# Accuracy at threshold 0.13 is 0.5513595166163142
# 2020-05-02 05:19:47 INFO     F1 score at threshold 0.14 is 0.5920114122681883
# Accuracy at threshold 0.14 is 0.56797583081571
# 2020-05-02 05:19:47 INFO     F1 score at threshold 0.15 is 0.5927536231884059
# Accuracy at threshold 0.15 is 0.5755287009063444
# 2020-05-02 05:19:47 INFO     F1 score at threshold 0.16 is 0.5988112927191679
# Accuracy at threshold 0.16 is 0.5921450151057401
# 2020-05-02 05:19:47 INFO     F1 score at threshold 0.17 is 0.6074411541381929
# Accuracy at threshold 0.17 is 0.6095166163141994
# 2020-05-02 05:19:47 INFO     F1 score at threshold 0.18 is 0.6108979278587874
# Accuracy at threshold 0.18 is 0.6170694864048338
# 2020-05-02 05:19:47 INFO     F1 score at threshold 0.19 is 0.6111975116640747
# Accuracy at threshold 0.19 is 0.622356495468278
# 2020-05-02 05:19:47 INFO     F1 score at threshold 0.2 is 0.6150197628458498
# Accuracy at threshold 0.2 is 0.6321752265861027
# 2020-05-02 05:19:47 INFO     F1 score at threshold 0.21 is 0.617363344051447
# Accuracy at threshold 0.21 is 0.6404833836858006
# 2020-05-02 05:19:47 INFO     F1 score at threshold 0.22 is 0.6245901639344261
# Accuracy at threshold 0.22 is 0.6540785498489426
# 2020-05-02 05:19:47 INFO     F1 score at threshold 0.23 is 0.6278101582014988
# Accuracy at threshold 0.23 is 0.6623867069486404
# 2020-05-02 05:19:47 INFO     F1 score at threshold 0.24 is 0.6322033898305084
# Accuracy at threshold 0.24 is 0.6722054380664653
# 2020-05-02 05:19:47 INFO     F1 score at threshold 0.25 is 0.6284246575342467
# Accuracy at threshold 0.25 is 0.6722054380664653
# 2020-05-02 05:19:47 INFO     F1 score at threshold 0.26 is 0.634315424610052
# Accuracy at threshold 0.26 is 0.6812688821752266
# 2020-05-02 05:19:47 INFO     F1 score at threshold 0.27 is 0.6338893766461808
# Accuracy at threshold 0.27 is 0.6850453172205438
# 2020-05-02 05:19:47 INFO     F1 score at threshold 0.28 is 0.631858407079646
# Accuracy at threshold 0.28 is 0.6858006042296072
# 2020-05-02 05:19:47 INFO     F1 score at threshold 0.29 is 0.6333630686886708
# Accuracy at threshold 0.29 is 0.6895770392749244
# 2020-05-02 05:19:47 INFO     F1 score at threshold 0.3 is 0.6348920863309352
# Accuracy at threshold 0.3 is 0.6933534743202417
# 2020-05-02 05:19:47 INFO     F1 score at threshold 0.31 is 0.6393442622950819
# Accuracy at threshold 0.31 is 0.7009063444108762
# 2020-05-02 05:19:47 INFO     F1 score at threshold 0.32 is 0.6439114391143912
# Accuracy at threshold 0.32 is 0.7084592145015106
# 2020-05-02 05:19:47 INFO     F1 score at threshold 0.33 is 0.6429240862230553
# Accuracy at threshold 0.33 is 0.7122356495468278
# 2020-05-02 05:19:47 INFO     F1 score at threshold 0.34 is 0.6425855513307984
# Accuracy at threshold 0.34 is 0.716012084592145
# 2020-05-02 05:19:47 INFO     F1 score at threshold 0.35 is 0.6467181467181468
# Accuracy at threshold 0.35 is 0.7235649546827795
# 2020-05-02 05:19:47 INFO     F1 score at threshold 0.36 is 0.6516634050880626
# Accuracy at threshold 0.36 is 0.7311178247734139
# 2020-05-02 05:19:47 INFO     F1 score at threshold 0.37 is 0.6534653465346535
# Accuracy at threshold 0.37 is 0.7356495468277946
# 2020-05-02 05:19:47 INFO     F1 score at threshold 0.38 is 0.6586586586586586
# Accuracy at threshold 0.38 is 0.7424471299093656
# 2020-05-02 05:19:47 INFO     F1 score at threshold 0.39 is 0.6585612968591692
# Accuracy at threshold 0.39 is 0.7454682779456193
# 2020-05-02 05:19:47 INFO     F1 score at threshold 0.4 is 0.6625641025641027
# Accuracy at threshold 0.4 is 0.7515105740181269
# 2020-05-02 05:19:47 INFO     F1 score at threshold 0.41 is 0.6590909090909091
# Accuracy at threshold 0.41 is 0.7507552870090635
# 2020-05-02 05:19:47 INFO     F1 score at threshold 0.42 is 0.6562824506749739
# Accuracy at threshold 0.42 is 0.75
# 2020-05-02 05:19:47 INFO     F1 score at threshold 0.43 is 0.6561181434599156
# Accuracy at threshold 0.43 is 0.7537764350453172
# 2020-05-02 05:19:47 INFO     F1 score at threshold 0.44 is 0.6503198294243071
# Accuracy at threshold 0.44 is 0.7522658610271903
# 2020-05-02 05:19:47 INFO     F1 score at threshold 0.45 is 0.645091693635383
# Accuracy at threshold 0.45 is 0.7515105740181269
# 2020-05-02 05:19:47 INFO     F1 score at threshold 0.46 is 0.6478260869565218
# Accuracy at threshold 0.46 is 0.7552870090634441
# 2020-05-02 05:19:47 INFO     F1 score at threshold 0.47 is 0.6482910694597573
# Accuracy at threshold 0.47 is 0.7590634441087614
# 2020-05-02 05:19:47 INFO     F1 score at threshold 0.48 is 0.6482300884955752
# Accuracy at threshold 0.48 is 0.7598187311178247
# 2020-05-02 05:19:47 INFO     F1 score at threshold 0.49 is 0.6479190101237347
# Accuracy at threshold 0.49 is 0.763595166163142
# 2020-05-02 05:19:47 INFO     F1 score at threshold 0.5 is 0.6476624857468642
# Accuracy at threshold 0.5 is 0.7666163141993958
# 2020-05-02 05:19:47 INFO     F1 score at threshold 0.51 is 0.6442641946697567
# Accuracy at threshold 0.51 is 0.7681268882175226
# 2020-05-02 05:19:48 INFO     F1 score at threshold 0.52 is 0.6393442622950821
# Accuracy at threshold 0.52 is 0.7673716012084593
# 2020-05-02 05:19:48 INFO     F1 score at threshold 0.53 is 0.6332138590203107
# Accuracy at threshold 0.53 is 0.7681268882175226
# 2020-05-02 05:19:48 INFO     F1 score at threshold 0.54 is 0.6310679611650486
# Accuracy at threshold 0.54 is 0.770392749244713
# 2020-05-02 05:19:48 INFO     F1 score at threshold 0.55 is 0.6266829865361077
# Accuracy at threshold 0.55 is 0.7696374622356495
# 2020-05-02 05:19:48 INFO     F1 score at threshold 0.56 is 0.6246913580246912
# Accuracy at threshold 0.56 is 0.770392749244713
# 2020-05-02 05:19:48 INFO     F1 score at threshold 0.57 is 0.6277915632754342
# Accuracy at threshold 0.57 is 0.7734138972809668
# 2020-05-02 05:19:48 INFO     F1 score at threshold 0.58 is 0.6257822277847309
# Accuracy at threshold 0.58 is 0.7741691842900302
# 2020-05-02 05:19:48 INFO     F1 score at threshold 0.59 is 0.6261089987325729
# Accuracy at threshold 0.59 is 0.777190332326284
# 2020-05-02 05:19:48 INFO     F1 score at threshold 0.6 is 0.6221079691516709
# Accuracy at threshold 0.6 is 0.7779456193353474
# 2020-05-02 05:19:48 INFO     F1 score at threshold 0.61 is 0.6189856957087125
# Accuracy at threshold 0.61 is 0.7787009063444109
# 2020-05-02 05:19:48 INFO     F1 score at threshold 0.62 is 0.6167979002624672
# Accuracy at threshold 0.62 is 0.7794561933534743
# 2020-05-02 05:19:48 INFO     F1 score at threshold 0.63 is 0.6108897742363878
# Accuracy at threshold 0.63 is 0.7787009063444109
# 2020-05-02 05:19:48 INFO     F1 score at threshold 0.64 is 0.6040268456375839
# Accuracy at threshold 0.64 is 0.777190332326284
# 2020-05-02 05:19:48 INFO     F1 score at threshold 0.65 is 0.5940054495912807
# Accuracy at threshold 0.65 is 0.7749244712990937
# 2020-05-02 05:19:48 INFO     F1 score at threshold 0.66 is 0.5914718019257221
# Accuracy at threshold 0.66 is 0.775679758308157
# 2020-05-02 05:19:48 INFO     F1 score at threshold 0.67 is 0.5821727019498607
# Accuracy at threshold 0.67 is 0.7734138972809668
# 2020-05-02 05:19:48 INFO     F1 score at threshold 0.68 is 0.5734463276836158
# Accuracy at threshold 0.68 is 0.7719033232628398
# 2020-05-02 05:19:48 INFO     F1 score at threshold 0.69 is 0.5632183908045978
# Accuracy at threshold 0.69 is 0.770392749244713
# 2020-05-02 05:19:48 INFO     F1 score at threshold 0.7 is 0.5627705627705628
# Accuracy at threshold 0.7 is 0.7711480362537765
# 2020-05-02 05:19:48 INFO     F1 score at threshold 0.71 is 0.5563689604685212
# Accuracy at threshold 0.71 is 0.7711480362537765
# 2020-05-02 05:19:48 INFO     F1 score at threshold 0.72 is 0.5422222222222223
# Accuracy at threshold 0.72 is 0.7666163141993958
# 2020-05-02 05:19:48 INFO     F1 score at threshold 0.73 is 0.5375375375375375
# Accuracy at threshold 0.73 is 0.7673716012084593
# 2020-05-02 05:19:48 INFO     F1 score at threshold 0.74 is 0.5290519877675841
# Accuracy at threshold 0.74 is 0.7673716012084593
# 2020-05-02 05:19:48 INFO     F1 score at threshold 0.75 is 0.5186335403726707
# Accuracy at threshold 0.75 is 0.7658610271903323
# 2020-05-02 05:19:48 INFO     F1 score at threshold 0.76 is 0.5031446540880503
# Accuracy at threshold 0.76 is 0.7613293051359517
# 2020-05-02 05:19:48 INFO     F1 score at threshold 0.77 is 0.5015873015873016
# Accuracy at threshold 0.77 is 0.7628398791540786
# 2020-05-02 05:19:48 INFO     F1 score at threshold 0.78 is 0.48953301127214177
# Accuracy at threshold 0.78 is 0.7605740181268882
# 2020-05-02 05:19:48 INFO     F1 score at threshold 0.79 is 0.4845528455284553
# Accuracy at threshold 0.79 is 0.7605740181268882
# 2020-05-02 05:19:48 INFO     F1 score at threshold 0.8 is 0.46434494195688225
# Accuracy at threshold 0.8 is 0.7560422960725075

# %%
# plot two measures
plt.plot(threshes, f1_scores, color='blue', label='f1')
plt.plot(threshes, accuracy_scores, color='orange', label='acc')
plt.title('f1_scores/acc')
plt.ylabel('f1_scores/acc')
plt.xlabel('threshold')
plt.legend()
plt.show()

# %% [markdown]
# ## Model4: CNN

# %%
logging.info('=========done===========')
# Out:
# 2020-05-02 05:24:39 INFO     =========done===========
